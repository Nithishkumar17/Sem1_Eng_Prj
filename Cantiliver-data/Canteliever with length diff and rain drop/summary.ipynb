# %%
# %store -r refined_peak_freq_01
# %store -r refined_peak_freq_02
# %store -r refined_peak_freq_03

print(f"Refined Fitted Peak from Drop 1: {refined_peak_freq_01:.4f} Hz")
print(f"Refined Fitted Peak from Drop 2: {refined_peak_freq_02:.4f} Hz")
print(f"Refined Fitted Peak from Drop 3: {refined_peak_freq_03:.4f} Hz")

average_refined_peak_freq = (refined_peak_freq_01 + refined_peak_freq_02 + refined_peak_freq_03) / 3
print(f"Average Refined Fitted Peak Frequency: {average_refined_peak_freq:.4f} Hz")
# Out:
# Refined Fitted Peak from Drop 1: 358.0929 Hz
# Refined Fitted Peak from Drop 2: 358.3236 Hz
# Refined Fitted Peak from Drop 3: 358.5016 Hz
# Average Refined Fitted Peak Frequency: 358.3060 Hz
